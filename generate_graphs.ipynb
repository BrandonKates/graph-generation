# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
import networkx as nx
from matplotlib import pyplot as plt

from generate_graphs import *

#from utils import load_graph_list, draw_graph_list
#from create_graphs import create
#from args import Args
#arguments = Args()
#print(arguments.max_num_node)
#print(arguments.graph_type)
#graphs = create(arguments)
#print(len(graphs))

# %%
# Plot a bunch of MST's
args = Args()
graphs, msts, poses = create(args)
plot(graphs,msts,poses)

# %%
# One graph/mst/pos
i = 0
G = graphs[i]
T = msts[i]
pos = poses[i]

# %%
print(pos)
print()
print(T.edges())
# Out:
# {0: array([0.36872249, 0.3106436 ]), 1: array([0.69393919, 0.67963434]), 2: array([0.56147758, 0.87151838]), 3: array([0.03312847, 0.38299724]), 4: array([0.52354865, 0.43625978]), 5: array([0.54644898, 0.63087633]), 6: array([0.96155666, 0.49731654]), 7: array([0.75679067, 0.43494793]), 8: array([0.97554703, 0.7920046 ]), 9: array([0.25485732, 0.34701805])}
#
# [(0, 9), (0, 4), (9, 3), (1, 5), (1, 2), (5, 4), (4, 7), (6, 7), (6, 8)]

# %%
keys = sorted(pos.keys())
array_of_points = list(np.array([pos[key] for key in keys]).flatten())
output = T.edges()
type(output)
# Out:
# list
