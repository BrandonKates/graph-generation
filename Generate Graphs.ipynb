# %%
from utils import load_graph_list, draw_graph_list
from create_graphs import create
from args import Args

import numpy as np
import networkx as nx
arguments = Args()
print(arguments.max_num_node)
print(arguments.graph_type)
graphs = create(arguments)
print(len(graphs))
# Out:
# 10
# community4
# Creating dataset with  4  communities
# 3000

# %%
draw_graph_list(graphs[0:35], row=6,col=6)
# Out:
# /nfs01/shared_software/anaconda3/envs/graphgen/lib/python3.7/site-packages/networkx/drawing/nx_pylab.py:522: MatplotlibDeprecationWarning: The is_string_like function was deprecated in version 2.1.
#   if not cb.is_string_like(edge_color) \
# /nfs01/shared_software/anaconda3/envs/graphgen/lib/python3.7/site-packages/networkx/drawing/nx_pylab.py:543: MatplotlibDeprecationWarning: The is_string_like function was deprecated in version 2.1.
#   if cb.is_string_like(edge_color) or len(edge_color) == 1:

# %%
sample_graph = graphs[0]

# %%
# %matplotlib inline
nx.drawing.nx_pylab.draw_networkx(sample_graph)
# Out:
# /nfs01/shared_software/anaconda3/envs/graphgen/lib/python3.7/site-packages/networkx/drawing/nx_pylab.py:724: MatplotlibDeprecationWarning: The is_string_like function was deprecated in version 2.1.
#   if not cb.is_string_like(label):

# %%
for (u,v,weight) in sample_graph.edges(data=True):
    sample_graph.add_edge(u,v,weight=np.random.random())

# %%
T = nx.minimum_spanning_tree(sample_graph)
print(sorted(T.edges(data=True)))
# Out:
# [(0, 4, {'weight': 0.21553651516172712}), (3, 5, {'weight': 0.14478141169040393}), (3, 13, {'weight': 0.035991309692884554}), (5, 1, {'weight': 0.18100687345126365}), (7, 3, {'weight': 0.1417444345654194}), (7, 14, {'weight': 0.035803602673063484}), (8, 0, {'weight': 0.3072003384024049}), (9, 10, {'weight': 0.22010985726991805}), (9, 11, {'weight': 0.0581155354911177}), (9, 12, {'weight': 0.173639382083831}), (11, 2, {'weight': 0.17623469426382665}), (12, 15, {'weight': 0.0969383291197099}), (13, 6, {'weight': 0.06653058928134659}), (13, 9, {'weight': 0.10391554013273097}), (14, 8, {'weight': 0.04616758721678649}), (15, 50, {'weight': 0.1884540276914145}), (17, 29, {'weight': 0.028651790366580276}), (18, 21, {'weight': 0.05704921935274743}), (18, 23, {'weight': 0.06940983815208834}), (18, 28, {'weight': 0.16706435969885602}), (19, 28, {'weight': 0.08771054866244243}), (20, 24, {'weight': 0.06137165262205557}), (20, 27, {'weight': 0.2245928871306101}), (22, 20, {'weight': 0.029880132588555597}), (22, 26, {'weight': 0.13203318711956458}), (22, 32, {'weight': 0.00591182583445482}), (22, 38, {'weight': 0.1618798719155773}), (23, 16, {'weight': 0.10030494014078051}), (25, 30, {'weight': 0.014818089047640703}), (26, 18, {'weight': 0.06503599338040067}), (26, 31, {'weight': 0.02934352522063577}), (30, 17, {'weight': 0.03924846794404502}), (32, 25, {'weight': 0.062209876425550203}), (33, 34, {'weight': 0.12657909421958247}), (33, 35, {'weight': 0.10792218028873324}), (33, 36, {'weight': 0.2602898823506914}), (33, 40, {'weight': 0.00012986952027860266}), (33, 53, {'weight': 0.2665290620612677}), (34, 37, {'weight': 0.17504089105460752}), (39, 44, {'weight': 0.14487535529789597}), (40, 38, {'weight': 0.12090903135298625}), (40, 41, {'weight': 0.17697736769499472}), (41, 42, {'weight': 0.07847719973207534}), (42, 43, {'weight': 0.117787147061031}), (44, 37, {'weight': 0.265516144471598}), (46, 50, {'weight': 0.2340153426679782}), (47, 52, {'weight': 0.1205264512494062}), (47, 54, {'weight': 0.11012152204329173}), (48, 51, {'weight': 0.019306621154256187}), (48, 53, {'weight': 0.04470674799292906}), (49, 45, {'weight': 0.08694347122951951}), (49, 53, {'weight': 0.21542444808972327}), (49, 55, {'weight': 0.03157933441396332}), (52, 46, {'weight': 0.12250487054727721}), (52, 56, {'weight': 0.22472303030759921}), (55, 54, {'weight': 0.15313724273886686})]

# %%
# %matplotlib inline
nx.drawing.nx_pylab.draw_networkx(T)
